# %% [markdown]
# # VPython notebook testing
# ## Trying to get this to work is insane
# (It's definitely a government conspiracy)

# %%
from vpython import *
import numpy as np
# %vpython inline
# Out:
# C:\Users\vaugh\PyCharmMiscProject\.venv\Lib\site-packages\vpython\__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# <div id="glowscript" class="glowscript"></div>
# UsageError: Line magic function `%vpython` not found.

# %%
testSphere = sphere()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 testSphere = sphere()
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\vpython\vpython.py:1189, in sphere.__init__(self, **args)
#    1187 args['_default_size'] = vector(2,2,2)
#    1188 args['_objName'] = "sphere"
# -> 1189 super(sphere, self).setup(args)
#    1190 self._sizing = False
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\vpython\vpython.py:612, in standardAttributes.setup(self, args)
#     611 def setup(self, args):
# --> 612     super(standardAttributes, self).__init__()
#     613     self._constructing = True  ## calls to setters are from constructor
#     615     objName = self._objName = args['_objName']  ## identifies object type
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\vpython\vpython.py:265, in baseObj.__init__(self, **kwargs)
# ...

# %%
incrementx = 1
incrementy = 1
while True:
    rate(100)
    testSphere.pos.x += incrementx
    testSphere.pos.y += incrementy

    if testSphere.pos.x > 40:
        incremenxt = -1

    if testSphere.pos.x < -40:
        incrementx = 1

    if testSphere.pos.y > 40:
        incrementy = -1

    if testSphere.pos.y < -40:
        incrementy = 1
